# %%
a = 10
print(a)
# Out:
# 10

# %%
a = 10
b = 10.5
c = "Hello World"
d = True 
print(a)
print(b)
print(c)
print(a, b, c, d)
print(type(d))
type(a)
# Out:
# 10
# 10.5
# Hello World
# 10 10.5 Hello World True
# <class 'bool'>
# int

# %%
#Arathmetic operator or Mathematical Operator 
# + - * / %  ** // this are used as operator

# %%
a = 10 
b = 2
print(a + b) #Add
print(a - b) #sub
print(a * b) # Mul
print(a/b)   #div
print(a % b) #mod
print(a ** b) #power
print(a // b) # no decimal
# Out:
# 12
# 8
# 20
# 5.0
# 0
# 100
# 5

# %%
# string 
a = "Hello"
b = "world"
c = a + b
print(c)
# Out:
# Helloworld

# %%
a = "Hello World \n"
b = a*2
print(b)
# Out:
# Hello World
# Hello World

# %%
# bool
a = True
b = True
print(a*b)
# Out:
# 1

# %%
#Operator Types

# %%
#Data Type Conversion
a = 10 
b = float(a)
print(b)
# Out:
# 10.0

# %%
a = 10.5
b = int(a)
print(b)
# Out:
# 10

# %%
a = "10"
b = int(a)
print(b)
type(a)
type(b)
# Out:
# 10
# int

# %%
a = 1
b = bool(a)
print(a)
# Out:
# 1

# %%
#Note any number can be true and onle 0 is false
#any string is true only no string inside "" is false
a = 100
b = bool(a)
c = ""
d = bool(c)
print(b,d)
# Out:
# True False

# %%
a = 10.5
b = str(a)
print(b)
# Out:
# 10.5

# %%
#IO operation 
#input() this function is used to get input

# %%
a = input("Enter the number of a")
print(a)
type(a) # when ther is only input it only take input as string value
# Out:
# Enter the number of a 10
# 10
# str

# %%
a = int(input("Enter a = "))
b = int(input("Enter b = "))
c = a+b
print(f"value of a is ",c)
# Out:
# Enter a =  10
# Enter b =  20
# value of a is  30

# %%
p = int(input("Enter p = "))
t = int(input("Enter t = "))
r = int(input("Enter r = "))
i = (p*t*r)/100
print(f"Simple interst is ",i)
# Out:
# Enter p =  50
# Enter t =  600
# Enter r =  1
# Simple interst is  300.0

# %%
name = input("Enter name = ")
age = int(input("Enter age : "))
add = input("Enter address: ")
print("Hello world I am", name , "I am form", add, "I am ",age,"old")
# Out:
# Enter name =  10
# Enter age :  20
# Enter address:  30
# Hello world I am 10 I am form 30 I am  20 old

# %%
info = "Hello world I am "+ name + "I am from "+ add+ "I am " + str(age) + "."
print(info)
# Out:
# Hello world I am 10I am from 30I am 20.

# %%
a = 10
b = str(a)
print(b)
# Out:
# 10

# %%
# conditional Operator
# != == <= => < > 
a = 10 
b = 20 
print(a == b)
print(a != b)
print(a <= b)
print(a > b)
print(a < b)
# print(a => b)
# print(a <= b)
# Out:
# False
# True
# True
# False
# True

# %%
 #communication f
