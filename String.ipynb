# %%
a = 'Hello World'
b = "Hello World"
c = """HHello World"""
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
a = 'Hello'
b = 'world'
c = a + " "+ b 
print(c)
# Out:
# Hello world

# %%
a = "Hello World \n"
print(a * 2)
# Out:
# Hello World
# Hello World

# %%
# String are immutable no change are allowed and string is itterable 
a = "Hello World"
print(a[0:2])
# Out:
# H

# %%
# it is immutable how
name = "Sara"
name[0] = "R"
 # this is not allowsd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # it is immutable how
#       2 name = "Sara"
# ----> 3 name[0] = "R"
#
# TypeError: 'str' object does not support item assignment

# %%
# this is ittereable beacuse You can go through each character one by one
a = "World Hello"
print(a[0:5])
print(a[5:])
# Out:
# World
#  Hello

# %%
# Mirroring
a = "Samira"
print(a[::-1])
# Out:
# arimaS

# %%
a = input("Enter a = ")
b = a[::-1]
if(a == b):
    print(f"{a} is pallendrome ")
else:
    print("It's not pallendrome")
# Out:
# Enter a =  101
# 101 is pallendrome

# %%
# String Formatting 
name = input("Enter Name: ")
age = int(input("Enter age: "))
add = input("Enter add: ")
info = "Hello Raj i am "

# %%
a = 10
a
type(a)
# Out:
# int

# %% [markdown]
# ## String Immutability
# ### Strings are immutable, which means that they cannot be changed after they are created. If we need to manipulate strings then we can use methods like concatenation, slicing or formatting to create new strings based on original.
# ### Example: In this example we are changing first character by building a new string.

# %%
s = "Raj"
s = "S" + s[1:]
print(s)
# Out:
# Saj

# %% [markdown]
# ## Deleting a String
# ### In Python, it is not possible to delete individual characters from a string since strings are immutable. However, we can delete an entire string variable using the del keyword.
# ### Example: Here, we are using del keyword to delete a string.

# %%
a = "Simran"
del a 
print(a)
### working
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 a = "Simran"
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## Updating a String
# ### As strings are immutable, “updates” create new strings using slicing or methods such as replace().
# ### Example: This code fix the first letter and replace a word.

# %%
a = "Dharamraj"
a1 = "d" + a[1:] # updating the string 
a2=  a.replace("Dharamraj", "Raj")
print(a1)
print(a2)
# Out:
# dharamraj
# Raj

# %%
## len()
a = "Sara"
print(len(a))
# Out:
# 4

# %%
### upper and lower
s = "sAmira"
print(s.upper())
print(s.lower())
# Out:
# SAMIRA
# samira

# %%
# strip() and replace()
s = "    Gfg"
print(s.strip())


s = "Pyhton is fun"
print(s.replace("fun","Hello"))
# Out:
# Gfg
# Pyhton is Hello

# %%
name = input("Enter Name = ")
age = int(input("Enter age = "))
add = input("Entert Address = ")
# This is known as string formatting.
info = f"Hello World I am {name}. I am from {add}. My age is {age}"
print(info)
# Out:
# Enter Name =  Samira
# Enter age =  23
# Entert Address =  Bkt

# %%
s = ""
n = int(input("Enter n = "))
for i in range(n):
    name = input("Enter name = ")
    phone = int(input("Enter phone no = "))
    info = f"{name} {phone}\n"
    s = s + info

print(s)
# Out:
# Enter n =  2
# Enter name =  Raj
# Enter phone no =  9862478815
# Enter name =  Samira
# Enter phone no =  9805674711
# Raj 9862478815
# Samira 9805674711

# %%
from datetime import datetime

now = datetime.now()
date_string = now.strftime("%y-%m-%d %H:%M")

bill_lines = ""
sub_total = 0

n = int(input("Enter n = "))
for i in range(n):
    name = input("Product Name: ")
    price = int(input("Entert price = "))
    qty = float(input("Enter qty: "))
    total = price * qty

    info = f"{name:^15} {price:^10} {qty:^5} {total:^10.2f}\n"
    bill_lines = bill_lines + info
    sub_total = sub_total + total

vat_rate = 0.13
vat_amount = sub_total * vat_rate
grand_total = sub_total + vat_amount

print("\n" + "="*45)
print("      SAMIRAJ KIRANA PASAL BHAKTAPUR")
print(f"Date: {date_string}")
print("="*45)


print(f"{'Product':<15} {'Price':<10} {'Qty':<5} {'Total':<10}")
print("-" * 45)


print(bill_lines, end="")

print("-" * 45)
# Totals and Tax Breakdown
print(f"{'Sub-Total':<32} Rs. {sub_total:>8.2f}")
print(f"{'VAT (13%)':<32} Rs. {vat_amount:>8.2f}")
print("-" * 45)
print(f"{'GRAND TOTAL':<32} Rs. {grand_total:>8.2f}")
print("="*45)
print("        Thank you for your visit!")
# Out:
# ...
#       SAMIRAJ KIRANA PASAL BHAKTAPUR
# Date: 26-03-03 12:53
# ...
# Product         Price      Qty   Total
# ---------------------------------------------
#      Momo          200      2.0    400.00
#      Coke           50      5.0    250.00
# ---------------------------------------------
# Sub-Total                        Rs.   650.00
# VAT (13%)                        Rs.    84.50
# ---------------------------------------------
# GRAND TOTAL                      Rs.   734.50
# ...
#         Thank you for your visit!

# %%
print(f"{'Samira':<5} {'Raj':<10}")
print(f"{'Samira':^2}")
print(f"{'Name':^15}{'Age':^10}")
print("-" * 25)
print(f"{'Samira':^15}{22:^10}")
print(f"{'Raj':^15}{25:^10}")
# Out:
# Samira Raj
# Samira
#      Name         Age
# -------------------------
#     Samira         22
#       Raj          25

# %%
# WAP to create a result management system 
s = int(input("Enter the total number of Students: "))
Total_mark = 0
average = 0 
for i in range(s):
    phy = int(input("Enter mark of PHY: "))
    che = int(input("Enter mark of CHE: "))
    nep = int(input("Enter mark of NEP: "))
    mat = int(input("Enter mark of MAT: "))
    eng = int(input("Enter mark of ENG: "))
    com = int(input("Enter mark of COM: "))
    total_mark = phy + che + nep + mat + eng + com 
    average = total_mark / 6
    cgpa = average/25

# %%
s = int(input("Enter the total number of students: "))
database = {}
for i in range(s):
    print(f"\n--- Entering data for Student {i+1} ---")
    roll = input("Enter Roll Number: ")
    name = input("Enter Student Name: ")
    phy = int(input("Enter mark of PHY: "))
    che = int(input("Enter mark of CHE: "))
    nep = int(input("Enter mark of NEP: "))
    mat = int(input("Enter mark of MAT: "))
    eng = int(input("Enter mark of ENG: "))
    com = int(input("Enter mark of COM: "))
    total_mark = phy + che + nep + mat + eng + com 
    average = total_mark / 6
    cgpa = average / 25 

    database[roll] = {
        "name": name,
        "marks":{"PHY":phy, "CHE":che, "NEP":nep, "ENG":eng, "MAT": mat, "COM":com},
        "total":total_mark,
        "avg": round(average, 2),
        "cgpa": round(cgpa, 2)
    }

while True:
    print("\n" + "="*30)
    search_roll = input("Enter Roll Number to view Marksheet (or 'exit' to quit): ")
    
    if search_roll.lower() == 'exit':
        break
    
    if search_roll in database:
        std = database[search_roll]
        print("\n" + "*"*40)
        print(f"       STUDENT MARKSHEET")
        print("*"*40)
        print(f"Name: {std['name']}")
        print(f"Roll No: {search_roll}")
        print("-" * 40)
        
        # Loop through marks to display subjects
        for subject, score in std['marks'].items():
            print(f"{subject:<10}: {score}")
            
        print("-" * 40)
        print(f"GRAND TOTAL: {std['total']}/600")
        print(f"AVERAGE    : {std['avg']}%")
        print(f"CGPA       : {std['cgpa']}")
        print("*"*40)
    else:
        print("Error: Roll Number not found!")

# %% [markdown]
# ## Student Result Management System

# %%
symbol_number = int(input("Enter sybol number: "))
name = input("Enter your name: ")

phy = int(input("Enter mark of PHY: "))
che = int(input("Enter mark of CHE: "))
nep = int(input("Enter mark of NEP: "))
mat = int(input("Enter mark of MAT: "))
eng = int(input("Enter mark of ENG: "))
com = int(input("Enter mark of COM: "))
total = phy + che + nep + mat + eng + com 
average = total / 6
cgpa = average / 25 
info = f"Symbol Number: {symbol_number}\nName: {name}\n total: {total}\n average: {average}\n cgpa: {cgpa}"
print("*" * 40)
print(f"{'Mount Valley English School':^40}")
print(f"{'Chyamasing, Bhaktapur ':^40}")
print("*" * 40)
print(f"{'STUDENT MARKSHEET':^40}")
print("-" * 40)
print(f'{'Symbol No. :'}{symbol_number:<15} {'Name :'}{name:<15}')
subjects = {"PHYSICS":phy, "CHEMISTRY":che, "NEPALI":nep, "MATH":mat, "ENGLISH":eng, "COMPUTER":com}
print("-" * 40)
print(f"{'SUBJECT':<20}| {'MARKS':>15}")
print("-" * 40)
for subject, mark in subjects.items():
    print(f"{subject:<20}| {mark:>15}")
    print("-" * 40)
print(f"{'GRAND TOTAL':<20}: {total:>15}")
print(f"{'AVERAGE':<20}: {average:>15.2f}")
print(f"{'CGPA':<20}: {cgpa:>15.2f}")
if cgpa >= 3.6:
    grade = "A+"
elif cgpa >= 3.2:
    grade = "A"
elif cgpa >= 2.8:
    grade = "B+"
elif cgpa >= 2.4:
    grade = "B"
elif cgpa >= 2.0:
    grade = "C+"
elif cgpa >= 1.6:
    grade = "C"
elif cgpa >= 1.0:
    grade = "D"
else:
    grade = "F"
print(f"{'GRADE':<20}: {grade:>15}")
print("-" * 40)
# Out:
# ****************************************
#       Mount Valley English School
#          Chyamasing, Bhaktapur
# ----------------------------------------
#            STUDENT MARKSHEET
# ----------------------------------------
# Symbol No. :1001            Name :Samira
# ----------------------------------------
# SUBJECT             |           MARKS
# ----------------------------------------
# PHYSICS             |              85
# ----------------------------------------
# CHEMISTRY           |              95
# ----------------------------------------
# NEPALI              |              96
# ----------------------------------------
# MATH                |             100
# ----------------------------------------
# ENGLISH             |              99
# ----------------------------------------
# COMPUTER            |              85
# ----------------------------------------
# GRAND TOTAL         :             560
# AVERAGE             :           93.33
# ...

# %% [markdown]
# # Multiple Student Result Management
# ## Using String for the grading system
# ### Date: March- 04 - 2026
# 1. input user name
# 2. input subject marks
# 3. calculate total marks, average, gpa and grade
# 4. output showing the result

# %%
n = int(input("Enter number of students: "))

for i in range(n):

    print("\nEnter details for Student", i+1)

    symbol_number = input("Enter Symbol Number: ")
    name = input("Enter student name: ")

    phy = int(input("Enter mark of Physics: "))
    che = int(input("Enter mark of Chemistry: "))
    nep = int(input("Enter mark of Nepali: "))
    mat = int(input("Enter mark of Math: "))    
    eng = int(input("Enter mark of English: "))
    com = int(input("Enter mark of Computer: "))

    total = phy + che + nep + mat + eng + com
    average = total / 6
    cgpa = average / 25

    print("*" * 40)
    print(f"{'Mount Valley English School':^40}")
    print(f"{'Chyamasing, Bhaktapur':^40}")
    print("*" * 40)
    print(f"{'STUDENT MARKSHEET':^40}")
    print("-" * 40)

    print(f"Symbol No.: {symbol_number:<10} Name: {name}")

    subjects = {
        "PHYSICS": phy,
        "CHEMISTRY": che,
        "NEPALI": nep,
        "MATH": mat,
        "ENGLISH": eng,
        "COMPUTER": com
    }

    print("-" * 40)
    print(f"{'SUBJECT':<20}| {'MARKS':>15}")
    print("-" * 40)

    for subject, mark in subjects.items():
        print(f"{subject:<20}| {mark:>15}")

    print("-" * 40)
    print(f"{'GRAND TOTAL':<20}: {total}")
    print(f"{'AVERAGE':<20}: {average:.2f}")
    print(f"{'CGPA':<20}: {cgpa:.2f}")

    if cgpa >= 3.6:
        grade = "A+"
    elif cgpa >= 3.2:
        grade = "A"
    elif cgpa >= 2.8:
        grade = "B+"
    elif cgpa >= 2.4:
        grade = "B"
    elif cgpa >= 2.0:
        grade = "C+"
    elif cgpa >= 1.6:
        grade = "C"
    elif cgpa >= 1.0:
        grade = "D"
    else:
        grade = "F"

    print(f"{'GRADE':<20}: {grade}")
    print("-" * 40)
# Out:
# Enter details for Student 1
# ****************************************
#       Mount Valley English School
#          Chyamasing, Bhaktapur
# ****************************************
#            STUDENT MARKSHEET
# ----------------------------------------
# Symbol No.: 1002       Name: Samira
# ----------------------------------------
# SUBJECT             |           MARKS
# ----------------------------------------
# PHYSICS             |              85
# CHEMISTRY           |              85
# NEPALI              |              85
# MATH                |              85
# ENGLISH             |              85
# COMPUTER            |              85
# ----------------------------------------
# GRAND TOTAL         : 510
# AVERAGE             : 85.00
# CGPA                : 3.40
# GRADE               : A
# ----------------------------------------
#
# Enter details for Student 2
# ****************************************
#       Mount Valley English School
# ...

# %%
a = "Hello World"
for i in a:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for i in range(5):
    print(i,"Hello World")
# Out:
# 0 Hello World
# 1 Hello World
# 2 Hello World
# 3 Hello World
# 4 Hello World

# %%
a = "How we are doing"
print(len(a))
# Out:
# 16

# %%
for i in range(len(a)):
    print(a[i])
# Out:
# H
# o
# w
#
# w
# e
#
# a
# r
# e
#
# d
# o
# i
# n
# g

# %%
a ="Samira"
i = 0
while i < len(a):
    print(a[i], end = "")   # end = "" is used to print in the same line
    i = i +1
# Out:
# Samira

# %%
a = "Hello World. I am python programmer"
for i in a:
    if i != ".":
        print(i, end = "")
# this program will update the i one by one and print in the same line because of end = ""
# Out:
# Hello World I am python programmer

# %%
a = "Hello world. I am Python "
for i in a:
    if i != ".":
        print(i, end = "")
    else:
        print(".")
        #break 
        continue
# Out:
# Hello world.
#  I am Python

# %%
a = "Ram Shyam Hari Sita Gita Rita"
name = input("Enter name for search:")
if name in a:
    print(f"Name Found: {name}")
else:
    print(f"Name not found: {name}")
# Out:
# Name Found: Ram

# %%
a = "Ram Shyam Hari Sita Gita Rita"
print(a.upper())
print(a.lower())
# Out:
# RAM SHYAM HARI SITA GITA RITA
# ram shyam hari sita gita rita

# %%
print(a)
# Out:
# Ram Shyam Hari Sita Gita Rita

# %%
a = "Ram Shyam Hari Sita Gita Rita".lower()
name = input("Enter name for search:").lower()
if name in a:
    print("Yes There is ")
    print(a.count(name))
else:
    print("No there is not")
# Out:
# Yes There is
# 1

# %%
a = "Shyam Raj Sita"
a = a.replace("Shyam", "Samira")
a = a.replace("Sita", "")  
print(a)
# Out:
# Samira Raj

# %%
a = "Shyam Raj Sita"
name = input("Enter name for search:")
if name in a: 
    print("Yes there is")
    a = a.replace(name, "")
    print(a)
else:
    print("No there is not")
# Out:
# Yes there is
# Shyam Raj

# %% [markdown]
# # str/list.count(ele, start, end) //Syntax of count
# ### single character are not counted the words are counted
