# %% [markdown]
# Syntax
# if <condition>:
#    <operation>
# elif <condition>:
#    <operation>
# else:
#    <operation>

# %%
a = 10
age = int(input("Enter age =  "))
if age >= a:
    print("Welcome to Team")
else:
    print("You are Under Age")
# Out:
# Enter age =   15
# Welcome to Team

# %% [markdown]
# ## Even Number Finding

# %%
a = int(input("Enter a Number: "))
if a % 2 == 0:
    print("It is even number")
else:
    print("this is odd number")
# Out:
# Enter a Number:  3
# this is odd number

# %%
a = int(input("Enter a = "))
b = int(input("Enter b = "))
if a > b:
    print(a,"is grater than" , b)
elif b>a:
    print(b,"is grater than" , a)
else:
    print(a, "=",b)
# Out:
# Enter a =  16
# Enter b =  8
# 16 is grater than 8

# %%
physics = int(input("Enter physics = "))
chemistry = int(input("Enter Chemistry = "))
math = int(input("Enter math = "))
english = int(input("Enter english = "))
nepali = int(input("Enter neplai = "))

total = physics + chemistry  + math + english + nepali
avg = total/5

if avg >= 80:
    grade = "A"
elif avg >= 60:
    grade = "B"
elif avg >= 40:
    grade = "C"
else:
    grade = "F"

print("The total marks = ", total)
print("The Average is ", avg)
print("The Grade = ",grade)
# Out:
# Enter physics =  95
# Enter Chemistry =  60
# Enter math =  90
# Enter english =  85
# Enter neplai =  70
# The total marks =  400
# The Average is  80.0
# The Grade =  A

# %%
num1 = int(input("Enter the first Number: "))
num2 = int(input("Enter the second Number: "))
op = input("Enter the Operator: ")
if op == "+":
    result = num1 + num2
    print(result)
elif op == "-":
    result = num1 - num2
    print(result)
elif op == "/" and num2 != 0:
    result = num1 /num2
    print(result)
elif op == "/" and num2 == 0:
    print("Value of num2 cannot be zero")
else:
    print("Message: Invalid Operator")
# Out:
# Enter the first Number:  5
# Enter the second Number:  0
# Enter the Operator:  /
# Value of num2 cannot be zero

# %%
# Logical Operator 
# and or not operator 
#workign with multiple operator

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False )
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False )
# Out:
# True
# True
# True
# False

# %%
print(not True)
print(not False)
# Out:
# False
# True

# %%
physics = int(input("Enter physics = "))
chemistry = int(input("Enter Chemistry = "))
math = int(input("Enter math = "))
english = int(input("Enter english = "))
nepali = int(input("Enter neplai = "))

total = physics + chemistry  + math + english + nepali
avg = total/5

if (avg > 80) or ( avg == 80):
    grade = "A"
elif (avg > 60) or (avg == 60):
    grade = "B"
elif (avg > 40) or (avg == 40):
    grade = "C"
else:
    grade = "F"

print("The total marks = ", total)
print("The Average is ", avg)
print("The Grade = ",grade)
# Out:
# Enter physics =  40
# Enter Chemistry =  35
# Enter math =  20
# Enter english =  21
# Enter neplai =  40
# The total marks =  156
# The Average is  31.2
# The Grade =  F

# %%
# Nested if else statement in python used when condition inside condition is needed 
# if <condition>:
#     if<condition>:
#         <operation>
#     else:
#         <operation>
# else:
      # .......
#     <operation>

# %%
a = int(input("Enter a = "))
if a>=0:
    if a%2==0:
        print("")

# %%
a = int(input("Enter the a "))
b = int(input("Enter the b "))
c = int(input("Enter the c "))
if (a == b) and (b == c) and ( c == a):
    print("eq")
elif (a == b) or (b ==c) or (c ==a ):
    print("iso")

else:
    print("sc")322222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222
# Out:
# Enter the a  2
# Enter the b  3
# Enter the c  4
# sc
