# %% [markdown]
# Inheritance is the capability of one class to derive or inherit the properties from some another class
# It provides reusability
# Parent class and child class

# %%
# Syntax
# class A:
#     <methods1>
#     <methods2>

# class B(A):
#     <methods3>
#     <methods4>

# obj = B()
# obj.<methods1>
# obj.<methods3>

# %%
class Data:
    def __init__(self,name,age,add):
        self.name = name
        self.age = age
        self.add = add
    
    def data(self):
        print(self.name,self.age, self.add)


class Info(Data):
    # def __init__(self):
    #     Data.__init__(self)
    #     self.phone = input("Enter the phone no. : ")
        

    def info(self):
        a = f"Hello world {self.name}. I am from {self.add}. I am {self.age}."
        print(a)

name = input("Enter the name = ")
age = input("Enter the age = ")
add = input("Enter the add = ")
obj = Info(name, age, add)
obj.info()
obj.data()
# Out:
# Hello world Samira. I am from Bkt. I am 9862478815.
# Samira 9862478815 Bkt

# %%
class Data:
    def __init__(self,name,age,add):
        self.name = name
        self.age = age
        self.add = add
    
    def data(self):
        print(self.name,self.age, self.add)


class Info(Data):
    def __init__(self,name,age,add,phone):
        self.phone = phone
        Data.__init__(self,name,age,add)

        

    def info(self):
        a = f"Hello world {self.name}. I am from {self.add}. I am {self.age}. My phone number is {self.phone}"
        print(a)

name = input("Enter the name = ")
age = input("Enter the age = ")
add = input("Enter the add = ")
phone = input("Enter the phone number: ")
obj = Info(name, age, add,phone)
obj.info()
obj.data()
# Out:
# Hello world Samira. I am from Bkt. I am 23. My phone number is 9862478815
# Samira 23 Bkt

# %%
#Types 
#Multi Level Inheretence
# Multiple Inheretance

# %%
# #Multi Leval Inheritance
# class A:
#     pass
# class B(A):
#     pass
# class c(B):
#     pass

# obj = c()

# %%
class MyAddress:
    def __init__(self,add):
        self.add = add
    
    def adds(self):
        print(self.add)


class Data(MyAddress):
    def __init__(self,name,age,add):
        self.name = name
        self.age = age
        # self.add = add
        MyAddress.__init__(self,add)
    
    def data(self):
        print(self.name,self.age, self.add)


class Info(Data):
    def __init__(self,name,age,add,phone):
        self.phone = phone
        Data.__init__(self,name,age,add)

        

    def info(self):
        a = f"Hello world {self.name}. I am from {self.add}. I am {self.age}. My phone number is {self.phone}"
        print(a)

name = input("Enter the name = ")
age = input("Enter the age = ")
add = input("Enter the add = ")
phone = input("Enter the phone number: ")
obj = Info(name, age, add,phone)
obj.info()
obj.data()
obj.adds()
# Out:
# Hello world Samira. I am from Bkt. I am 23. My phone number is 9862478815
# Samira 23 Bkt
# Bkt

# %%
class Address:
    def __init__(self,add):
        self.add = add

class Data:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
class Info (Address, Data):
    def __init__(self,name, age, add,phone):
        self.phone = phone
        Data.__init__(self,name,age)
        Address.__init__(self,add)
    def display(self):
        a = f"Hello world {self.name}. I am from {self.add}. I am {self.age}. My phone number is {self.phone}"
        print(a)

name = input("Enter the name = ")
age = input("Enter the age = ")
add = input("Enter the add = ")
phone = input("Enter the phone number: ")
obj = Info(name, age, add,phone)
obj.display()
# Out:
# Hello world Samira. I am from Bhaktapur. I am 23. My phone number is 9862477815

# %%
# public member
class Info:
    def __init__(self):
        self.__name = "Ram"
        self.__age = 45
        self.__add = "Bkt"
    
obj = Info()
# print(obj.__name)
# print(obj.__age)
# print(obj.__add)

# %%
class Address:
    def __init__(self,add):
        self.__add = add
        self.addi =self.__add
    
class Data:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
class Info (Address, Data):
    def __init__(self,name, age, add,phone):
        self._phone =phone
        Data.__init__(self,name,age)
        Address.__init__(self,add)
    def display(self):
        a = f"Hello world {self.name}.  I am {self.age}. My phone number is {self._phone}. I am from {self.addi}"
        print(a)

name = input("Enter the name = ")
age = input("Enter the age = ")
add = input("Enter the add = ")
phone = input("Enter the phone number: ")
obj = Info(name, age, add,phone)
obj.display()
# Out:
# Hello world Samira.  I am 23. My phone number is 852. I am from Bkt

# %%
class Data:
    def __init__(self, name, age, add):
        self.name = name
        self._age = age
        self.__add = add
    
    def data(self):
        print(self.name, self._age, self.__add)
    
    def myadd(self):
        return self.__add
    
class Info(Data):
    def info(self):
        ad = Data.myadd(self)
        a = f"Hello world I am {self.name}. I am form {ad}. I am {self._age}"
        print(a)


name = input("Enter the name = ")
age = input("Enter the age = ")
add = input("Enter the add = ")
phone = input("Enter the phone number: ")
obj = Info(name, age, add)
obj.info()
obj.data()
# Out:
# Hello world I am Samira. I am form 123. I am 123
# Samira 123 123

# %%
# Polymorhism one name but many function
